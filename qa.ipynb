# %%
import matplotlib.pyplot as plt
import os
import pandas as pd

from rpt.stats_by_date import get_stats_by_date
from rpt.stats_by_hw import get_stats_by_hw

config = {
    "frame_folder": "frames",
    "hw_events_stats_file": "hw_events_stats.pickle",
    "card_events_file": "card_events.pickle",
    "hw_events_file": "hw_events.pickle",
}

pd.set_option('display.max_rows', 500)

start = pd.Timestamp.today() - pd.DateOffset(14, "D")
end = pd.Timestamp.today()

# %%
dt_rpt = get_stats_by_date(config, start, end).copy()

# %%
dt_rpt.head(10)
# Out:
#               reviewed  new  learned  forgot  netlearned  cumreviewed  cumnew  \
# revieweddate
# 2019-11-10          33    0        6       2           4           33       0
# 2019-11-12          43    0        8       6           2           76       0
# 2019-11-13          40    0        8       4           4          116       0
# 2019-11-14          45    0        7       6           1          161       0
# 2019-11-19          47    1        6      14          -8          208       1
# 2019-11-21         101    0       25       7          18          309       1
# 2019-11-22         218    2       47      15          32          527       3
#
#               cumnetlearned
# revieweddate
# 2019-11-10                4
# 2019-11-12                6
# 2019-11-13               10
# 2019-11-14               11
# 2019-11-19                3
# 2019-11-21               21
# 2019-11-22               53

# %%
hw_rpt = get_stats_by_hw(config, start, end).copy()

# %%
hw_rpt[hw_rpt['reviewed'] > 1].head(100)
# Out:
#       reviewed firstreviewed lastreviewed  correct  incorrect    new   knew  \
# hw
# 交换           2    2019-11-14   2019-11-22        1          1  False  False
# 伙伴           2    2019-11-10   2019-11-19        0          2  False  False
# 关闭           2    2019-11-21   2019-11-22        0          2  False  False
# 冲            2    2019-11-12   2019-11-22        0          2  False  False
# 分别           2    2019-11-19   2019-11-21        1          1  False   True
# 制定           2    2019-11-12   2019-11-21        0          2  False  False
# 叉子           2    2019-11-21   2019-11-22        0          2  False  False
# 咬            2    2019-11-10   2019-11-22        0          2  False   True
# 喊            2    2019-11-10   2019-11-19        0          2  False  False
# 均匀           2    2019-11-19   2019-11-21        0          2  False  False
# 墙            2    2019-11-14   2019-11-21        1          1  False   True
# 处理           2    2019-11-14   2019-11-22        1          1  False  False
# 姿势           2    2019-11-13   2019-11-22        0          2  False  False
# 字母           2    2019-11-12   2019-11-22        2          0  False   True
# 孝顺           2    2019-11-12   2019-11-21        0          2  False  False
# 学院           2    2019-11-13   2019-11-21        1          1  False   True
# 安装           2    2019-11-21   2019-11-22        1          1  False  False
# 宴会           2    2019-11-14   2019-11-22        0          2  False  False
# 忽视           2    2019-11-14   2019-11-19        0          2  False  False
# 想念           2    2019-11-13   2019-11-22        2          0  False  False
# 戏剧           2    2019-11-10   2019-11-22        0          2  False  False
# 批准           2    2019-11-10   2019-11-22        1          1  False  False
# 押金           2    2019-11-10   2019-11-12        0          2  False  False
# 握手           2    2019-11-13   2019-11-22        2          0  False  False
# 播放           2    2019-11-13   2019-11-22        1          1  False  False
# 救            2    2019-11-14   2019-11-21        0          2  False   True
# 无所谓          2    2019-11-12   2019-11-22        0          2  False  False
# 时光           2    2019-11-19   2019-11-21        1          1  False   True
# 枪            2    2019-11-13   2019-11-22        0          2  False   True
# 模特           2    2019-11-14   2019-11-21        1          1  False  False
# 欣赏           2    2019-11-12   2019-11-21        1          1  False  False
# 歪            2    2019-11-13   2019-11-14        0          2  False  False
# 淡            2    2019-11-21   2019-11-22        1          1  False  False
# 爱护           2    2019-11-13   2019-11-14        0          2  False  False
# 生产           2    2019-11-12   2019-11-22        1          1  False   True
# 称呼           2    2019-11-10   2019-11-13        0          2  False  False
# 简直           2    2019-11-12   2019-11-22        1          1  False  False
# 结合           2    2019-11-12   2019-11-19        2          0  False   True
# 结尾           2    2019-11-13   2019-11-19        0          2  False  False
# 绝对           2    2019-11-10   2019-11-13        1          1  False   True
# 老百姓          2    2019-11-21   2019-11-22        1          1  False   True
# 肥皂           2    2019-11-19   2019-11-21        0          2  False   True
# 舅舅           2    2019-11-21   2019-11-22        0          2  False  False
# 营业           2    2019-11-12   2019-11-22        0          2  False  False
# 营养           2    2019-11-10   2019-11-13        0          2  False  False
# 设施           2    2019-11-19   2019-11-21        0          2  False  False
# 设计           2    2019-11-19   2019-11-22        1          1  False   True
# 资格           2    2019-11-13   2019-11-22        1          1  False  False
# 过敏           2    2019-11-19   2019-11-21        0          2  False  False
# 逍遥法外         2    2019-11-21   2019-11-22        1          1  False  False
# 零食           2    2019-11-14   2019-11-22        1          1  False   True
# 颗            2    2019-11-21   2019-11-22        0          2  False  False
# 鼓掌           2    2019-11-10   2019-11-14        0          2  False  False
# 鼠标           2    2019-11-19   2019-11-22        1          1  False  False
#
#       learned  forgot   know        pinyin  \
# hw
# 交换       True   False   True      jiāohuàn
# 伙伴      False   False  False        huǒbàn
# 关闭      False   False  False        guānbì
# 冲       False   False  False         chōng
# 分别      False    True  False        fēnbié
# 制定      False   False  False       zhìdìng
# 叉子      False   False  False         chāzǐ
# 咬       False    True  False           yǎo
# 喊       False   False  False           hǎn
# 均匀      False   False  False        jūnyún
# 墙       False    True  False         qiáng
# 处理       True   False   True         chùlǐ
# 姿势      False   False  False         zīshì
# 字母      False   False   True          zìmǔ
# 孝顺      False   False  False      xiàoshùn
# 学院      False    True  False       xuéyuàn
# 安装       True   False   True      ānzhuāng
# 宴会      False   False  False        yànhùi
# 忽视      False   False  False         hūshì
# 想念       True   False   True     xiǎngniàn
# 戏剧      False   False  False          xìjù
# 批准       True   False   True        pīzhǔn
# 押金      False   False  False         yājīn
# 握手       True   False   True        wòshǒu
# 播放       True   False   True        bōfàng
# 救       False    True  False           jìu
# 无所谓     False   False  False      wúsuǒwèi
# 时光      False    True  False      shíguāng
# 枪       False    True  False         qiāng
# 模特       True   False   True          mótè
# 欣赏       True   False   True      xīnshǎng
# 歪       False   False  False           wāi
# 淡        True   False   True           dàn
# 爱护      False   False  False          àihù
# 生产      False    True  False     shēngchǎn
# 称呼      False   False  False       chēnghū
# 简直       True   False   True       jiǎnzhí
# 结合      False   False   True         jiéhé
# 结尾      False   False  False        jiéwěi
# 绝对      False    True  False        juédùi
# 老百姓     False    True  False    lǎobǎixìng
# 肥皂      False    True  False        féizào
# 舅舅      False   False  False        jìujìu
# 营业      False   False  False        yíngyè
# 营养      False   False  False      yíngyǎng
# 设施      False   False  False        shèshī
# 设计      False    True  False         shèjì
# 资格       True   False   True          zīgé
# 过敏      False   False  False        guòmǐn
# 逍遥法外     True   False   True  xiāoyáofǎwài
# 零食      False    True  False       língshí
# 颗       False   False  False            kē
# 鼓掌      False   False  False       gǔzhǎng
# 鼠标       True   False   True       shǔbiāo
#
#                                              definition
# hw
# 交换    [to exchange, to swap, to switch (telecom), co...
# 伙伴                        [partner, companion, comrade]
# 关闭                                  [to close, to shut]
# 冲     [powerful, vigorous, pungent, towards, in view...
# 分别    [to part or leave each other, to distinguish, ...
# 制定                           [to draw up, to formulate]
# 叉子                                    [fork, CL:把[ba3]]
# 咬                                  [variant of 咬[yao3]]
# 喊       [to yell, to shout, to call out for (a person)]
# 均匀    [even, well-distributed, homogeneous, well-pro...
# 墙                            [wall, CL:面[mian4],堵[du3]]
# 处理    [to handle, to treat, to deal with, to process...
# 姿势                                  [posture, position]
# 字母              [letter (of the alphabet), CL:個|个[ge4]]
# 孝顺      [filial piety, to be obedient to one's parents]
# 学院    [college, educational institute, school, facul...
# 安装    [to install, to erect, to fix, to mount, insta...
# 宴会    [banquet, feast, dinner party, CL:席[xi2],個|个[g...
# 忽视                              [to neglect, to ignore]
# 想念    [to miss, to remember with longing, to long to...
# 戏剧                               [drama, play, theater]
# 批准                              [to approve, to ratify]
# 押金                              [deposit, down payment]
# 握手                                     [to shake hands]
# 播放                          [to broadcast, to transmit]
# 救                       [to save, to assist, to rescue]
# 无所谓   [to be indifferent, not to matter, cannot be s...
# 时光                          [time, era, period of time]
# 枪                [variant of 槍|枪[qiang1], rifle, spear]
# 模特                         [(fashion) model (loanword)]
# 欣赏                 [to appreciate, to enjoy, to admire]
# 歪                        [to sprain (one's ankle) (Tw)]
# 淡     [insipid, diluted, weak, mild, light in color,...
# 爱护    [to cherish, to treasure, to take care of, to ...
# 生产    [to produce, to manufacture, to give birth to ...
# 称呼                [to call, to address as, appellation]
# 简直                        [simply, at all, practically]
# 结合    [to combine, to link, to integrate, binding, C...
# 结尾                           [ending, coda, to wind up]
# 绝对                            [absolute, unconditional]
# 老百姓   [ordinary people, the "person in the street", ...
# 肥皂                     [soap, CL:塊|块[kuai4],條|条[tiao2]]
# 舅舅    [mother's brother, maternal uncle (informal), ...
# 营业                           [to do business, to trade]
# 营养             [nutrition, nourishment, CL:種|种[zhong3]]
# 设施                           [facilities, installation]
# 设计      [plan, design, to design, to plan, CL:個|个[ge4]]
# 资格                          [qualifications, seniority]
# 过敏                   [oversensitive, allergic, allergy]
# 逍遥法外  [unfettered and beyond the law (idiom); evadin...
# 零食                       [between-meal nibbles, snacks]
# 颗     [classifier for small spheres, pearls, corn gr...
# 鼓掌                                [to applaud, to clap]
# 鼠标                                  [mouse (computing)]
